# %% [markdown]
# ## Methodology for preparing geojson of all states with data for onclick events
#
# 1. Start with US geojson from US Census
# 2. Bring into https://geojson.io and delete all the boundaries not wanted, save that file (us_all.geojson)
# 3. Prepare the csv file with the data for the onclick events (map_data.csv)
# 4. Read the geojson and the csv file into Pandas
# 5. Merge those two files using geopandas
# 6. Export the merge df as a shape file using geopandas
# 7. Convert the shape files to geojson using an online converter (https://mygeodata.cloud/converter/shp-to-geojson).
#
# Didn't use Dom's code because I couln't get the geometry to export. Left code at the bottom on notebook for future reference.

# %%
import pandas as pd
import geopandas
import json
import numpy as np
import fiona
# import fiona; help(fiona.open)

# %%
gdf = geopandas.read_file("US_map/us_all.geojson")
pdf = pd.read_csv("map_data_all.csv")

# %%
gdf
# Out:
#           AREA   PERIMETER  ST99_D00_  ST99_D00_I STATE        NAME LSAD  \
# 0   271.254384  227.171422          2           1    02      Alaska   01
# 1    25.539497   31.407183         83          82    27   Minnesota   01
# 2    20.853578   30.717392         84          83    53  Washington   01
# 3    45.078463   34.976231         86          85    30     Montana   01
# 4    24.456828   29.190335         87          86    16       Idaho   01
# ..         ...         ...        ...         ...   ...         ...  ...
# 58    0.058534    1.443311        255         254    15      Hawaii   01
# 59    0.163529    2.061015        256         255    15      Hawaii   01
# 60    0.031553    0.720769        257         256    15      Hawaii   01
# 61    0.009946    0.453710        258         257    15      Hawaii   01
# 62    0.898700    4.381072        259         258    15      Hawaii   01
#
#     REGION  DIVISION LSAD_TRANS  \
# 0        4         9       None
# 1        2         4       None
# 2        4         9       None
# 3        4         8       None
# 4        4         8       None
# ..     ...       ...        ...
# 58       4         9       None
# 59       4         9       None
# 60       4         9       None
# 61       4         9       None
# 62       4         9       None
#
#                                              geometry
# 0   POLYGON ((-147.78711 70.24536, -147.76510 70.2...
# 1   POLYGON ((-95.15332 49.19311, -95.15342 49.249...
# 2   POLYGON ((-122.29069 49.00243, -122.28565 49.0...
# 3   POLYGON ((-116.04919 49.00091, -116.00103 49.0...
# 4   POLYGON ((-116.04919 49.00091, -116.04918 48.8...
# ..                                                ...
# 58  POLYGON ((-156.98234 21.20780, -156.98446 21.2...
# 59  POLYGON ((-156.58683 21.02704, -156.58045 21.0...
# 60  POLYGON ((-157.01000 20.92976, -156.98981 20.9...
# 61  POLYGON ((-156.56714 20.60489, -156.55873 20.5...
# 62  POLYGON ((-155.63492 18.94609, -155.63805 18.9...
#
# [63 rows x 11 columns]

# %%
pdf
# Out:
#                     NAME State  AltFuelStn  ChgStns  ChgOut        Em05  \
# 0                Alabama    AL         814      172     432  172.421366
# 1                 Alaska    AK          73       37      67   56.171623
# 2                Arizona    AZ        2224      753    1907  110.289794
# 3               Arkansas    AR         516      124     390   84.293401
# 4             California    CA       39643    13096   33324  476.131228
# 5               Colorado    CO        3783     1331    3139  126.153712
# 6            Connecticut    CT        1403      448    1191   49.460796
# 7               Delaware    DE         276       98     248   18.735743
# 8   District of Columbia    DC         789      238     650    5.039416
# 9                Florida    FL        6584     2205    5427  296.084508
# 26    8.519563          19     1060665      54970
# 27   12.657120          17     1925614      61439
# 28   17.213761          22     3027341      60365
# 29    7.595320          27     1353465      76768
# 30   70.840195          34     8886025      82545
# 31   15.786081          22     2092741      49754
# 32   76.183372          51    19530351      68486
# 33   55.339745          33    10381615      54602
# 34    6.419279          19      758080      64894
# 35   73.243646          13    11676341      56602
# 36   31.648135          28     3940235      52919
# 37   24.012615          43     4181886      62818
# 38   74.695926          23    12800922      61744
# 39    4.509714          26     1058287      67167
# 40   31.437084          17     5084156      53199
# 41    6.257833          14      878698      58275
# 42   46.754846          19     6771631      53320
# 43  199.232214          31    28628666      61874
# 44   17.191121          30     3153550      71621
# 45    3.996870          29      624358      61973
# 46   57.112547          38     8501286      74222
# 47   44.593140          47     7523869      73775
# 48   12.935266          11     1804291      46711
# 49   31.331999          32     5807406      61747
# 50    8.517090          11      577601      64049

# %%
joined_gdf = gdf.merge(pdf, on="NAME")
joined_gdf
# Out:
#           AREA   PERIMETER  ST99_D00_  ST99_D00_I STATE        NAME LSAD  \
# 0   271.254384  227.171422          2           1    02      Alaska   01
# 1    25.539497   31.407183         83          82    27   Minnesota   01
# 2    20.853578   30.717392         84          83    53  Washington   01
# 3    45.078463   34.976231         86          85    30     Montana   01
# 4    24.456828   29.190335         87          86    16       Idaho   01
# ..         ...         ...        ...         ...   ...         ...  ...
# 58    0.058534    1.443311        255         254    15      Hawaii   01
# 59    0.163529    2.061015        256         255    15      Hawaii   01
# 60    0.031553    0.720769        257         256    15      Hawaii   01
# 61    0.009946    0.453710        258         257    15      Hawaii   01
# 62    0.898700    4.381072        259         258    15      Hawaii   01
#
#     REGION  DIVISION LSAD_TRANS  \
# 0        4         9       None
# 1        2         4       None
# 2        4         9       None
# 3        4         8       None
# 4        4         8       None
# ..     ...       ...        ...
# 58       4         9       None
# 59       4         9       None
# 60       4         9       None
# 61       4         9       None
# 62       4         9       None
#
#                                              geometry State  AltFuelStn  \
# 0   POLYGON ((-147.78711 70.24536, -147.76510 70.2...    AK          73
# 1   POLYGON ((-95.15332 49.19311, -95.15342 49.249...    MN        1964
# 2   POLYGON ((-122.29069 49.00243, -122.28565 49.0...    WA        4289
# 3   POLYGON ((-116.04919 49.00091, -116.00103 49.0...    MT         226
# 4   POLYGON ((-116.04919 49.00091, -116.04918 48.8...    ID         374
# ..                                                ...   ...         ...
# 58  POLYGON ((-156.98234 21.20780, -156.98446 21.2...    HI         837
# 59  POLYGON ((-156.58683 21.02704, -156.58045 21.0...    HI         837
# 60  POLYGON ((-157.01000 20.92976, -156.98981 20.9...    HI         837
# 61  POLYGON ((-156.56714 20.60489, -156.55873 20.5...    HI         837
# 62  POLYGON ((-155.63492 18.94609, -155.63805 18.9...    HI         837
#
#     ChgStns  ChgOut        Em05  Em05Trans  Incentives  Population  MedianInc
# 0        37      67   56.171623  19.245401           9      735139      77640
# 1       530    1185  133.031986  37.647662          36     5606249      71306
# 2      1499    3675   96.264174  44.593140          47     7523869      73775
# 3        63     191   50.843711   8.519563          19     1060665      54970
# 4       101     252   29.944624   8.965070          15     1750536      55785
# ..      ...     ...         ...        ...         ...         ...        ...
# 58      367     753   25.934498  13.084581          21     1420593      81275
# 59      367     753   25.934498  13.084581          21     1420593      81275
# 60      367     753   25.934498  13.084581          21     1420593      81275
# 61      367     753   25.934498  13.084581          21     1420593      81275
# 62      367     753   25.934498  13.084581          21     1420593      81275
#
# [63 rows x 20 columns]

# %%
list(joined_gdf.columns)
# Out:
# ['AREA',
#  'PERIMETER',
#  'ST99_D00_',
#  'ST99_D00_I',
#  'STATE',
#  'NAME',
#  'LSAD',
#  'REGION',
#  'DIVISION',
#  'LSAD_TRANS',
#  'geometry',
#  'State',
#  'AltFuelStn',
#  'ChgStns',
#  'ChgOut',
#  'Em05',
#  'Em05Trans',
#  'Incentives',
#  'Population',
#  'MedianInc']

# %%
# # Try writing to file using geopandas

# joined_gdf.to_file("test.geojson", driver="GeoJSON")

# %%
# Write to shape file

joined_gdf.to_file("all_final.shp")

# %% [markdown]
# ## Code from Dom

# %%
# # Define a helper function to format Geojson
# # Dom worked to customize this to convert data to dictionary

# def dfGeoJSON(joined_gdf):
#     geojson = {'type': 'FeatureCollection', 'features':[]}
    
#     for i in range(len(joined_gdf)):
        
#         dict = {}
#         dict['AREA'] = joined_gdf.iloc[i, 0]
#         dict['PERIMETER'] = joined_gdf.iloc[i, 1]
#         dict['NAME'] = joined_gdf.iloc[i, 5]
#         dict['geometry'] = joined_gdf.iloc[i, 10]
#         dict['State'] = joined_gdf.iloc[i, 11]
#         dict['AltFuelStations'] = joined_gdf.iloc[i, 12]
#         dict['ChargeStations'] = joined_gdf.iloc[i, 13]
#         dict['ChargeOutlets'] = joined_gdf.iloc[i, 14]
#         dict['2005Emissions(MtCO2)'] = joined_gdf.iloc[i, 15]
#         dict['2005EmissionsTrans(MtCO2)	'] = joined_gdf.iloc[i, 17]
#         dict['Incentives'] = joined_gdf.iloc[i, 19]
        
#         # feature = joined_gdf.iloc[i, 2]
#         geojson['features'].append(dict)
        
#     return geojson

# %%
# # Convert the updated dataframe back to a GeoJSON

# geojson = dfGeoJSON(joined_gdf)

# %%
#geojson

# %%
# # Define a helper function to deal with numpy datatypes

# def convert(o):
#     if isinstance(o, np.int64): return int(o)
# #     raise TypeError

# %%
# # Save the GeoJSON file

# with open("final_geojson.geojson", 'w') as file:
#     file.write(json.dumps(geojson, default=convert))

# %%
# Original code Dom provided

# # Define a helper function to format a GeoJSON
# def dfGeoJSON(df):
#     geojson = {'type': 'FeatureCollection', 'features': []}
#     for i in range(len(df)):
#         feature = df.iloc[i, 1]
#         geojson['features'].append(feature)
#     return geojson

# # Convert the updated dataframe back to a GeoJSON
# geojson = dfGeoJSON(df)

# # Define a helper function to deal with numpy datatypes
# def convert(o):
#     if isinstance(o, np.int64): return int(o)  
#     raise TypeError
    
# # Finally, save the new GeoJSON file
# with open(new_geojson_file, 'w') as file:
#      file.write(json.dumps(geojson, default=convert))
